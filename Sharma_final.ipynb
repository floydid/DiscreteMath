# %% [markdown]
# <a href="https://colab.research.google.com/github/floydid/DiscreteMath/blob/main/Sharma_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # : CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Graphs And Numbers
#
# ###  ID: Pawan Sharma (221121)

# %% [markdown]
# ## 1 Graphs

# %% [markdown]
# In this project, i will be using TV series "FRIENDS" to show a directed graph. All the five characters from the show will be used.

# %% [markdown]
# I would use python package graphviz to visualize the show's members graph.

# %%
import graphviz

graph = graphviz.Digraph('Friends graph ')

graph.edge('Monica', 'Ross', label = ' Brother')
graph.edge('Ross','Chandler',' Friend')
graph.edge('Chandler', 'Joey', label = ' Roomates' )
graph.edge('Chandler', 'Monica', 'Girlfriend')
graph.edge('Ross', 'Rachel', ' Lovers')
graph.edge('Phoebe', 'Monica', ' friend')
graph

# %% [markdown]
# Starting with Ross and Monica, thery are siblings. Joey and chadler are roomates. Rachel is Ross's lover and Chandler and Monica are dating. Phoebe knows everyone through Monica.

# %% [markdown]
# lets take a relationship between Monica and Joey. In order to describe a path in the graph, the path would go from Monica to Ross to Chandler and Joey.

# %% [markdown]
# Chandler, has 3 edges comming towards him. So the degree of vertex Chandler would be 3.

# %% [markdown]
# There is a cycle in the graph. the edges connecting Monica, Ross and Chandler are making a cycle.

# %% [markdown]
# ## 2 Numbers

# %% [markdown]
# Convert base 7 24036 to base 10

# %%
c = int('24036', 7)
c
# Out:
# 6201

# %% [markdown]
# Given hex number 72E3 and we have to convert it to base 10.

# %%
hex = int(0x72e3)
hex
# Out:
# 29411

# %% [markdown]
# Given decimal no is 3735928559

# %%
decimal = 3735928559
hex = hex(decimal)
hex
# Out:
# '0xdeadbeef'

# %% [markdown]
# The converted hex number is 0xDEADBEEF

# %% [markdown]
# Hexadecimal is used to store error messages, memory addresses, mac address. Binary number just includes 0 and 1 so it take too much space. two decimal number includes 8 bits in binary so it shortens the space needed. Also, for a programmer looking at binary  error codes will be too much complex so hexadecimal number comes in play.

# %% [markdown]
# Binary uses 0 and 1, and is also refered to as machine language. Basically computer uses 0 and 1 to store bits in memory or turn its logic gates on or off. A computer cannot process logic like we humans do, so a two option on or off logic is easiest so a computer has been designed and works around 0 and 1.

# %%
Given decimals 25 and -37. if were to subtract 25 form -37 we would get -12. However we just said a computer only understand 0 and 1.
 So we have to find two's complement of -12 in order for the computer to understand it.

# %%
num = -12

def convert(num, bits):
    c = bin(dec & int("1"*bits, 2))[2:]
    return ("{0:0>%s}" % (bits)).format(c)

convert(num,8)
# Out:
# '11110100'

# %% [markdown]
# I used 8 bits. If i were to only use 6 bits the ans would be 110100.

# %% [markdown]
# To check if i got the right answer

# %%
num = bin(25)
num
# Out:
# '0b11001'

# %%
num2 = bin(37)
num2
# Out:
# '0b100101'

# %% [markdown]
# 0b represents the numbers are binary

# %% [markdown]
# Actually we are given -37. We need to flip the bits and add 1 to it to get its two's complement.

# %%
num = "100101"
store = ""

for bit in num:
  if bit == "1":
    store += "0"
  else:
    store += "1"

print (store)
# Out:
# 011010

# %%
num = "011010"
num1 = "1"

add = int(num, 2) + int(num1, 2)
binary = bin(add)
print(binary)
# Out:
# 0b11011

# %% [markdown]
# 11011 is the two's complement of -37. Since two's complemet only takes addition, we take binary values of 25 and two's complement of -37 and add it together.

# %%
num1 = "11001"
num2 = "11011"

add = int(num1, 2) + int(num2, 2)
binary = bin(add).split("0b")[1]
print(binary)
# Out:
# 110100

# %% [markdown]
# 110100 verifies, it is two's complement of -12 in six bit form.
